# %%
import json
import os
import pandas as pd

# %%
os.chdir('/Users/NorieK/Desktop/DePaul/Spring 2017/CSC 478/Group Project Dataset')

# %%
with open('yelp_academic_dataset_business.json', 'r', encoding = 'utf8') as f: 
    data = f.readlines()

# %%
data = map(lambda x: x.rstrip(), data)
data_json_str = "[" + ','.join(data) + "]"
business_data = pd.read_json(data_json_str)

# %%
len(business_data['state'] == 'PA')
# Out:
# 144072

# %%
business_data['state'].unique()
# Out:
# array(['AZ', 'NV', 'ON', 'PA', 'BW', 'QC', 'NC', 'WI', 'OH', 'EDH', 'SC',
#        'WLN', 'IL', 'NI', 'MLN', 'STG', 'HLD', 'NY', 'FIF', 'NTH', 'ELN',
#        'FLN', 'ESX', 'SCB', 'KHL', 'FAL', 'PKN', 'VT', 'NLK'], dtype=object)

# %%
state_list = ['AZ', 'NV', 'PA', 'NC', 'WI', 'OH', 'SC', 'IL', 'NY', 'VT']
business_data_state = business_data[business_data.state == ('AZ')]
business_data_state
# Out:
#                                       address  \
# 6               10875 N Frankloyd Wright Blvd
# 7                 11072 No Frank Lloyd Wright
# 8                    11000 North 115th Street
# 13                        2525 W Carefree Hwy
# 16
# 19                   330 S Gilbert Rd, Ste 15
# 29                             5646 W Bell Rd
# 33                         1220 S Central Ave
# 45                    701 E Bethany Home Road
# 46                      3369 E Queen Creek Rd
# 47                        1480 E Motorplex Lp
# 52                          3557 W Dunlap Ave
# 53                        3567 W Northern Ave
# 62                 8400 S. Kyrene Rd, Ste 107
# 63                    1330 W Auto Dr, Ste 106
# 64                         12033 N 28th Drive
# 68                 3107 S Gilbert Rd, Ste 110
# 77                         170 E Corporate Pl
# 79                       7401 N Scottsdale Rd
# 83                        2034 E Southern Ave
# ...

# %%
business_data_state.append(business_data.state = 'PA')
# Out:
#   File "<ipython-input-50-cefe369a8c77>", line 1
#     business_data_state.append(business_data.state = 'PA')
#                               ^
# SyntaxError: keyword can't be an expression

# %%
business_data['state'].unique()
# Out:
# array(['ON', 'PA', 'AZ', 'BW', 'NV', 'QC', 'NC', 'WI', 'OH', 'EDH', 'SC',
#        'WLN', 'IL', 'NI', 'MLN', 'STG', 'HLD', 'NY', 'FIF', 'NTH', 'ELN',
#        'FLN', 'ESX', 'SCB', 'KHL', 'FAL', 'PKN', 'VT', 'NLK'], dtype=object)
