# %%
import pandas as pd
import os

# %%
os.chdir('/Users/NorieK/Desktop/DePaul/Spring 2017/CSC 478/Group Project Dataset')

# %%
business_data = pd.read_csv('yelp_biz_v2.csv', sep=',')
business_data.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-50-13fa9ff8d5b2> in <module>()
# ----> 1 business_data = pd.read_csv('yelp_notEcode.csv', sep=',')
#       2 business_data.head()
#
# ...

# %%
business_data.shape
# Out:
# (107303, 14)

# %%
business_data_state = business_data[business_data.state == ('NV')]
business_data_state
# Out:
#                                                   address  \
# 0                                495 S Grand Central Pkwy
# 18                                        4300 Meadows Ln
# 26                                     848 N Rainbow Blvd
# 38                                 9931 W Charleston Blvd
# 43                                      7329 S Jones Blvd
# 51                           4972 S Maryland Pkwy, Ste 22
# 52                       6569 S Las Vegas Blvd, Ste C 165
# 53                        Desert National Wildlife Refuge
# 71                                      7300 Aliante Pkwy
# 72                                       4949 N Rancho Dr
# 89                                   3830 Blue Diamond Rd
# 90                           7850 Dean Martin Dr, Ste 505
# 93                               855 S Grand Central Pkwy
# 100                             6088 S Durango Dr Ste 100
# 103           Inside Wildefire Casino, 2000 S Boulder Hwy
# ...

# %%
state_list = ['AZ', 'PA', 'NC', 'WI', 'OH', 'SC', 'IL', 'NY', 'VT']
for i in state_list:
    pa = business_data[business_data.state == (i)]
    business_data_state = business_data_state.append(pa)
business_data_state.head()
# Out:
#                      address  \
# 0   495 S Grand Central Pkwy
# 18           4300 Meadows Ln
# 26        848 N Rainbow Blvd
# 38    9931 W Charleston Blvd
# 43         7329 S Jones Blvd
#
#                                            attributes             business_id  \
# 0   ['BusinessAcceptsBitcoin: False', 'BusinessAcc...  LTlCaCGZE14GuaUXUGbamg
# 18  ['BusinessAcceptsCreditCards: True', 'Restaura...  AGN788ObhwXu7rb8MEejIA
# 26               ['BusinessAcceptsCreditCards: True']  XK5w8XnbP8CdeoB44kn1bg
# 38  ['BusinessAcceptsCreditCards: True', 'ByAppoin...  U8_JrQdIpuTKw60vjc1-cw
# 43               ['BusinessAcceptsCreditCards: True']  SGpnlO6TBpR_IFgOa3F8EQ
#
#                                            categories       city  \
# 0   ['Caterers', 'Grocery', 'Food', 'Event Plannin...  Las Vegas
# 18             ['Shoe Stores', 'Fashion', 'Shopping']  Las Vegas
# 26  ['Local Services', 'Notaries', 'Professional S...  Las Vegas
# ...

# %%
business_data_state.shape
# Out:
# (78621, 14)

# %%
with open('biz_json.json', 'r', encoding = 'utf8') as f: 
    data = f.readlines()

# %%
data = map(lambda x: x.rstrip(), data)
data_json_str = "[" + ','.join(data) + "]"
business_data = pd.read_json(data_json_str)

# %%
business_data.head()
# Out:
#                                              columns  \
# 0  [address, attributes, business_id, categories,...
#
#                                                 data  \
# 0  [[495 S Grand Central Pkwy, [BusinessAcceptsBi...
#
#                                                index
# 0  [1, 10, 11, 26, 36, 37, 54, 55, 61, 71, 72, 73...

# %%
with open('biz_json2.json', 'r', encoding = 'utf8') as f: 
    data = f.readlines()

# %%
data = map(lambda x: x.rstrip(), data)
data_json_str = "[" + ','.join(data) + "]"
business_data = pd.read_json(data_json_str)

# %%
business_data.head()
# Out:
#                                               0       \
# 0  [495 S Grand Central Pkwy, [BusinessAcceptsBit...
#
#                                               1       \
# 0  [2553 Wigwam Pkwy, None, MFneYHieJ_lnjMeFUGKVb...
#
#                                               2       \
# 0  [1500 N Green Valley Pkwy, Ste 230, [Alcohol: ...
#
#                                               3       \
# 0  [4300 Meadows Ln, [BusinessAcceptsCreditCards:...
#
#                                               4       \
# 0  [848 N Rainbow Blvd, [BusinessAcceptsCreditCar...
#
#                                               5       \
# 0  [4811 S Rainbow Blvd, [Alcohol: full_bar, Busi...
#
#                                               6       \
# 0  [9931 W Charleston Blvd, [BusinessAcceptsCredi...
#
#                                               7       \
# 0  [707 Fremont St, Ste 1340, [BikeParking: True,...
#
#                                               8       \
# ...
